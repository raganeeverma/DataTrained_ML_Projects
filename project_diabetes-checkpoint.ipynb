# %% [markdown]
# # Diabeties dataset

# %% [markdown]
# This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective is to predict based on diagnostic measurements whether a patient has diabetes.

# %% [markdown]
# Content
# Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.
#
# Pregnancies: Number of times pregnant
#
# Glucose: Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#
# BloodPressure: Diastolic blood pressure (mm Hg)
#
# SkinThickness: Triceps skin fold thickness (mm)
#
# Insulin: 2-Hour serum insulin (mu U/ml)
#
# BMI: Body mass index (weight in kg/(height in m)^2)
#
# DiabetesPedigreeFunction: Diabetes pedigree function
#
# Age: Age (years)
#
# Outcome: Class variable (0 or 1)

# %% [markdown]
# Number of Instances: 768
# Number of Attributes: 8 plus class
# For Each Attribute: (all numeric-valued)

# %% [markdown]
# # Gestational Diabetes

# %% [markdown]
# Gestational diabetes is a type of diabetes that can develop during pregnancy in women who don't already have diabetes. Every year, 2% to 10% of pregnancies in the United States are affected by gestational diabetes. Managing gestational diabetes will help make sure you have a healthy pregnancy and a healthy baby.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as st
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("diabetes.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#      pregnancy  glucose  bp  skinthickness  insulin   bmi    dpf  age  outcome
# 0            6      148  72             35        0  33.6  0.627   50        1
# 1            1       85  66             29        0  26.6  0.351   31        0
# 2            8      183  64              0        0  23.3  0.672   32        1
# 3            1       89  66             23       94  28.1  0.167   21        0
# 4            0      137  40             35      168  43.1  2.288   33        1
# ..         ...      ...  ..            ...      ...   ...    ...  ...      ...
# 763         10      101  76             48      180  32.9  0.171   63        0
# 764          2      122  70             27        0  36.8  0.340   27        0
# 765          5      121  72             23      112  26.2  0.245   30        0
# 766          1      126  60              0        0  30.1  0.349   47        1
# 767          1       93  70             31        0  30.4  0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.head()
# Out:
#    pregnancy  glucose  bp  skinthickness  insulin   bmi    dpf  age  outcome
# 0          6      148  72             35        0  33.6  0.627   50        1
# 1          1       85  66             29        0  26.6  0.351   31        0
# 2          8      183  64              0        0  23.3  0.672   32        1
# 3          1       89  66             23       94  28.1  0.167   21        0
# 4          0      137  40             35      168  43.1  2.288   33        1

# %%
df.sample(3)
# Out:
#      pregnancy  glucose  bp  skinthickness  insulin   bmi    dpf  age  outcome
# 439          6      107  88              0        0  36.8  0.727   31        0
# 116          5      124  74              0        0  34.0  0.220   38        1
# 179          5      130  82              0        0  39.1  0.956   37        1

# %%
df.info
# Out:
# <bound method DataFrame.info of      pregnancy  glucose  bp  skinthickness  insulin   bmi    dpf  age  outcome
# 0            6      148  72             35        0  33.6  0.627   50        1
# 1            1       85  66             29        0  26.6  0.351   31        0
# 2            8      183  64              0        0  23.3  0.672   32        1
# 3            1       89  66             23       94  28.1  0.167   21        0
# 4            0      137  40             35      168  43.1  2.288   33        1
# ..         ...      ...  ..            ...      ...   ...    ...  ...      ...
# 763         10      101  76             48      180  32.9  0.171   63        0
# 764          2      122  70             27        0  36.8  0.340   27        0
# 765          5      121  72             23      112  26.2  0.245   30        0
# 766          1      126  60              0        0  30.1  0.349   47        1
# ...

# %%
df.columns
# Out:
# Index(['pregnancy', 'glucose', 'bp', 'skinthickness', 'insulin', 'bmi', 'dpf',
#        'age', 'outcome'],
#       dtype='object')

# %%
df.shape
# Out:
# (768, 9)

# %%
df.dtypes
# Out:
# pregnancy          int64
# glucose            int64
# bp                 int64
# skinthickness      int64
# insulin            int64
# bmi              float64
# dpf              float64
# age                int64
# outcome            int64
# dtype: object

# %% [markdown]
# # null value

# %% [markdown]
# if 50% of data or more than is missing in perticuler column then drop that column atherwise fill it with mode or median value

# %%
df.isnull()
# Out:
#      pregnancy  glucose     bp  skinthickness  insulin    bmi    dpf    age  \
# 0        False    False  False          False    False  False  False  False
# 1        False    False  False          False    False  False  False  False
# 2        False    False  False          False    False  False  False  False
# 3        False    False  False          False    False  False  False  False
# 4        False    False  False          False    False  False  False  False
# ..         ...      ...    ...            ...      ...    ...    ...    ...
# 763      False    False  False          False    False  False  False  False
# 764      False    False  False          False    False  False  False  False
# 765      False    False  False          False    False  False  False  False
# 766      False    False  False          False    False  False  False  False
# 767      False    False  False          False    False  False  False  False
#
#      outcome
# 0      False
# 1      False
# ...

# %%
df.isnull().sum()
# Out:
# pregnancy        0
# glucose          0
# bp               0
# skinthickness    0
# insulin          0
# bmi              0
# dpf              0
# age              0
# outcome          0
# dtype: int64

# %%
df.isnull().sum().sum()# total no of null value in complete dataset
# Out:
# 0

# %%
sns.heatmap(df.isnull())##check missing value through visualization
# Out:
# <AxesSubplot:>

# %%
if null value is present this is removed by using

1 simple imputer ,knn imputer ,iterative imputer, fillna, inplace or drop the row with null value

categorical variable- replace by mode

continous  variable - replace by mean or median
# Out:
#   File "C:\Users\HP\AppData\Local\Temp/ipykernel_3444/1129653554.py", line 1
#     if null value is present this is removed by using
#             ^
# SyntaxError: invalid syntax

# %%
#eg of fillnan

#df["dpf"].fillna(value=df["dpf"].mean())

# %%
#eg of replace
# df['age'].replace(np.NaN,df['age'].mean,inplace=True)

# %%
#from sklearn.impute import SimpleImputer

#imp = SimpleImputer(strategy='most_frequent')#nan value replaced by mode value

#df['bmi']=imp.fit_transform(df['bmi'].values.reshape(-1,1))

# %% [markdown]
# # Duplicate value

# %%
# if duplicate value present drop this row
df.drop_duplicates()

# %%
#no duplicates bcz the row no. is same as before

# %% [markdown]
# # EDA

# %% [markdown]
# Descriptive analysid
#
# null value
#
# visualizatin
#
# correlation
#
# skewness

# %% [markdown]
# independ feature--> normal distribution--> remove skewness-->transformation
#
# outliers--> z score/IQR
#
# scalling --> normalization ,standarlization

# %% [markdown]
# machine learning prerecusite
#
# data should be normal distibution
#
# no outliers
#
# no null value
#
# same scale(range of all dataset is same)

# %% [markdown]
# # Scatterplot

# %%
import seaborn as sns

# %%
df.columns

# %%
sns.scatterplot(x='pregnancy',y='outcome',data=df)

# %%
# there is no bias or imbalance data bcz the no of week of pregnency is equaly distributed inthe range 0 to 13

# %%
sns.scatterplot(x='glucose', y='outcome',data=df)

# %%
sns.scatterplot(x='age', y='outcome',data=df)

# %%
sns.scatterplot(x='bp', y='outcome',data=df)

# %%
sns.scatterplot(x='skinthickness', y='outcome',data=df)

# %%
sns.scatterplot(x='insulin', y='outcome',data=df)
# Out:
# <AxesSubplot:xlabel='insulin', ylabel='outcome'>

# %%
sns.scatterplot(x='bmi', y='outcome',data=df)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='outcome'>

# %%
sns.scatterplot(x='dpf', y='outcome',data=df)
# Out:
# <AxesSubplot:xlabel='dpf', ylabel='outcome'>

# %%
# all plots are equaly distributet inrange so no need to balance if unbalance is present then use smote to balance the data

# %%
sns.pairplot(df) # column vs.column distribution plot 
plt.savefig("pairplot.png")
plt.show()

# %% [markdown]
# # Correlation

# %%
df.corr()#diagonaly correlation matrix
# Out:
#                pregnancy   glucose        bp  skinthickness   insulin  \
# pregnancy       1.000000  0.129459  0.141282      -0.081672 -0.073535
# glucose         0.129459  1.000000  0.152590       0.057328  0.331357
# bp              0.141282  0.152590  1.000000       0.207371  0.088933
# skinthickness  -0.081672  0.057328  0.207371       1.000000  0.436783
# insulin        -0.073535  0.331357  0.088933       0.436783  1.000000
# bmi             0.017683  0.221071  0.281805       0.392573  0.197859
# dpf            -0.033523  0.137337  0.041265       0.183928  0.185071
# age             0.544341  0.263514  0.239528      -0.113970 -0.042163
# outcome         0.221898  0.466581  0.065068       0.074752  0.130548
#
#                     bmi       dpf       age   outcome
# pregnancy      0.017683 -0.033523  0.544341  0.221898
# glucose        0.221071  0.137337  0.263514  0.466581
# bp             0.281805  0.041265  0.239528  0.065068
# ...

# %%
df.corr()["outcome"].sort_values()# correlatin all columns with outcome in assending order
# Out:
# bp               0.065068
# skinthickness    0.074752
# insulin          0.130548
# dpf              0.173844
# pregnancy        0.221898
# age              0.238356
# bmi              0.292695
# glucose          0.466581
# outcome          1.000000
# Name: outcome, dtype: float64

# %%
# correlation using heatmap

plt.figure(figsize=(15,7))
sns.heatmap(df.corr(),cmap='Blues',annot=True,linewidths=0.5,linecolor="black",fmt="0.2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# outcome from correlation
#
# all the column are positive correlation with target value
#
# pregnency is 22% correlation with outcome considered as good bond
#
# glucose is 47% correlation with outcome considered as strong bond
#
# bp is 7% correlation with outcome considered as weak bond
#
# skintickness is 7% correlation with outcome considered as  weak bond
#
# insulin 13% correlation with outcome considered as good bond
#
# bmi  is 29% correlation with outcome considered as good bond
#
# age is 24% correlation with outcome considered as good bond
#
# dpf is 17% correlation with outcome considered as good bond
#
#
# max correlation -glucose
# min correlation - bp,skinthickness
#
#
# we can drop the hightly negative correlation bond means negative values but there is not negative correlation

# %% [markdown]
# # Descriptive Stastics

# %%
df.describe()# it is used to find out variation
# Out:
#         pregnancy     glucose          bp  skinthickness     insulin  \
# count  768.000000  768.000000  768.000000     768.000000  768.000000
# mean     3.845052  120.894531   69.105469      20.536458   79.799479
# std      3.369578   31.972618   19.355807      15.952218  115.244002
# min      0.000000    0.000000    0.000000       0.000000    0.000000
# 25%      1.000000   99.000000   62.000000       0.000000    0.000000
# 50%      3.000000  117.000000   72.000000      23.000000   30.500000
# 75%      6.000000  140.250000   80.000000      32.000000  127.250000
# max     17.000000  199.000000  122.000000      99.000000  846.000000
#
#               bmi         dpf         age     outcome
# count  768.000000  768.000000  768.000000  768.000000
# mean    31.992578    0.471876   33.240885    0.348958
# std      7.884160    0.331329   11.760232    0.476951
# min      0.000000    0.078000   21.000000    0.000000
# 25%     27.300000    0.243750   24.000000    0.000000
# ...

# %%
df.describe()[1:]# no need of count values so remove it
# Out:
#       pregnancy     glucose          bp  skinthickness     insulin        bmi  \
# mean   3.845052  120.894531   69.105469      20.536458   79.799479  31.992578
# std    3.369578   31.972618   19.355807      15.952218  115.244002   7.884160
# min    0.000000    0.000000    0.000000       0.000000    0.000000   0.000000
# 25%    1.000000   99.000000   62.000000       0.000000    0.000000  27.300000
# 50%    3.000000  117.000000   72.000000      23.000000   30.500000  32.000000
# 75%    6.000000  140.250000   80.000000      32.000000  127.250000  36.600000
# max   17.000000  199.000000  122.000000      99.000000  846.000000  67.100000
#
#            dpf        age   outcome
# mean  0.471876  33.240885  0.348958
# std   0.331329  11.760232  0.476951
# min   0.078000  21.000000  0.000000
# 25%   0.243750  24.000000  0.000000
# 50%   0.372500  29.000000  0.000000
# 75%   0.626250  41.000000  1.000000
# max   2.420000  81.000000  1.000000

# %%
df.describe()[1:].transpose()

# transpose fun is convert row to column and column to row  used when large no. of column present for easy to analys
# Out:
#                      mean         std     min       25%       50%        75%  \
# pregnancy        3.845052    3.369578   0.000   1.00000    3.0000    6.00000
# glucose        120.894531   31.972618   0.000  99.00000  117.0000  140.25000
# bp              69.105469   19.355807   0.000  62.00000   72.0000   80.00000
# skinthickness   20.536458   15.952218   0.000   0.00000   23.0000   32.00000
# insulin         79.799479  115.244002   0.000   0.00000   30.5000  127.25000
# bmi             31.992578    7.884160   0.000  27.30000   32.0000   36.60000
# dpf              0.471876    0.331329   0.078   0.24375    0.3725    0.62625
# age             33.240885   11.760232  21.000  24.00000   29.0000   41.00000
# outcome          0.348958    0.476951   0.000   0.00000    0.0000    1.00000
#
#                   max
# pregnancy       17.00
# glucose        199.00
# bp             122.00
# skinthickness   99.00
# insulin        846.00
# bmi             67.10
# dpf              2.42
# ...

# %%
round(df.describe()[1:].transpose(),2)
# Out:
#                  mean     std    min    25%     50%     75%     max
# pregnancy        3.85    3.37   0.00   1.00    3.00    6.00   17.00
# glucose        120.89   31.97   0.00  99.00  117.00  140.25  199.00
# bp              69.11   19.36   0.00  62.00   72.00   80.00  122.00
# skinthickness   20.54   15.95   0.00   0.00   23.00   32.00   99.00
# insulin         79.80  115.24   0.00   0.00   30.50  127.25  846.00
# bmi             31.99    7.88   0.00  27.30   32.00   36.60   67.10
# dpf              0.47    0.33   0.08   0.24    0.37    0.63    2.42
# age             33.24   11.76  21.00  24.00   29.00   41.00   81.00
# outcome          0.35    0.48   0.00   0.00    0.00    1.00    1.00

# %%
# variation in heatmap

plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2),annot=True,linewidths=0.5,fmt="0.2f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=18)
plt.title("variation summary")
plt.savefig("heatmap.png")
plt.show()

# fmt is used for floting value rounded upto 2

# %% [markdown]
# # outcome from describe
#
# it helps to analysis pf the skewness and outliers prencent
#
# eg. pregnency 50% is 3 min value is 0 and and max value is 17 meand 50% of value is come in 0-3 and 50% value comes in 3-17 so there is skewness ptent no normal distribution
#
#
# eg.large gap between 75% and max value of insulin means many outliers are prent

# %%
df.info # how much memory needs IN RAM to run my dataframe and datatypes of columns just obervation
# Out:
# <bound method DataFrame.info of      pregnancy  glucose  bp  skinthickness  insulin   bmi    dpf  age  outcome
# 0            6      148  72             35        0  33.6  0.627   50        1
# 1            1       85  66             29        0  26.6  0.351   31        0
# 2            8      183  64              0        0  23.3  0.672   32        1
# 3            1       89  66             23       94  28.1  0.167   21        0
# 4            0      137  40             35      168  43.1  2.288   33        1
# ..         ...      ...  ..            ...      ...   ...    ...  ...      ...
# 763         10      101  76             48      180  32.9  0.171   63        0
# 764          2      122  70             27        0  36.8  0.340   27        0
# 765          5      121  72             23      112  26.2  0.245   30        0
# 766          1      126  60              0        0  30.1  0.349   47        1
# ...

# %% [markdown]
# # CHECK OUTLIERS PRESENT

# %%
collist=df.columns.values
ncol=30 # random no 
nrow=14

# %%
collist
# Out:
# array(['pregnancy', 'glucose', 'bp', 'skinthickness', 'insulin', 'bmi',
#        'dpf', 'age', 'outcome'], dtype=object)

# %%
len(list(range(0,len(collist))))
# Out:
# 9

# %%
range(0,len(collist))
# Out:
# range(0, 9)

# %%
for i in range(0,len(collist)):
    print(collist[i])
    break
# Out:
# pregnancy

# %% [markdown]
# prerequisite
#
# 1 normal distribution means skewness=0 use transformation
# 2 should be same range use scalling(standared or minmax scaller)
# 3 no null value (imputer)
# 4 no outliers (box plot, z-score,IQR)
#
# skewness=> outliers=> transformation=> continues data=> independent features
#
# S O T not perform in target variable or categorical data

# %% [markdown]
# # SKEWNESS

# %%
df.skew()
# Out:
# pregnancy        0.901674
# glucose          0.173754
# bp              -1.843608
# skinthickness    0.109372
# insulin          2.272251
# bmi             -0.428982
# dpf              1.919911
# age              1.129597
# outcome          0.635017
# dtype: float64

# %% [markdown]
# outcome of the skewness
# skewness thresold is taken as +-o.65
# column which are having skewed-
# pregnancy ,insulin  ,bp,dpf,age

# %% [markdown]
# # NORMAL DISTRIBUTION CURVE
#
# (finding the how much skewed)

# %%
sns.distplot(df['pregnancy'])
# Out:
# <AxesSubplot:xlabel='pregnancy', ylabel='Density'>

# %% [markdown]
# this is not normal distribution and skewness is present so we have to remove skewness using transformation

# %%
sns.distplot(df['glucose'])
# Out:
# <AxesSubplot:xlabel='glucose', ylabel='Density'>

# %%
sns.distplot(df['insulin'])
# Out:
# <AxesSubplot:xlabel='insulin', ylabel='Density'>

# %%
sns.distplot(df['bp'])
# Out:
# <AxesSubplot:xlabel='bp', ylabel='Density'>

# %% [markdown]
# # DATA CLEANING

# %%
#finding correlating input column with target data

df.corr()['outcome'].sort_values()# sort value in assending order
# Out:
# bp               0.065068
# skinthickness    0.074752
# insulin          0.130548
# dpf              0.173844
# pregnancy        0.221898
# age              0.238356
# bmi              0.292695
# glucose          0.466581
# outcome          1.000000
# Name: outcome, dtype: float64

# %% [markdown]
# the bp and skinthickness is very less correlated with outcomes so we can drop this two columns

# %%
delete=pd.DataFrame([[" 0.065068","bp","No","Alot"],["0.074752","skinthickness","No","Alot"]],
columns=["correlation with target","column name","normalise","outliers"])

delete # only visulization purpose
# Out:
#   correlation with target    column name normalise outliers
# 0                0.065068             bp        No     Alot
# 1                0.074752  skinthickness        No     Alot

# %%
df=df.drop(["bp","skinthickness"],axis=1)
df
# Out:
#      pregnancy  glucose  insulin   bmi    dpf  age  outcome
# 0            6      148        0  33.6  0.627   50        1
# 1            1       85        0  26.6  0.351   31        0
# 2            8      183        0  23.3  0.672   32        1
# 3            1       89       94  28.1  0.167   21        0
# 4            0      137      168  43.1  2.288   33        1
# ..         ...      ...      ...   ...    ...  ...      ...
# 763         10      101      180  32.9  0.171   63        0
# 764          2      122        0  36.8  0.340   27        0
# 765          5      121      112  26.2  0.245   30        0
# 766          1      126        0  30.1  0.349   47        1
# 767          1       93        0  30.4  0.315   23        0
#
# [768 rows x 7 columns]

# %% [markdown]
# # REMOVING OUTLIERS

# %% [markdown]
# Z score/IQR

# %%
from scipy.stats import zscore
zscore(df) # zscore value have  positive and negative value both
# Out:
#      pregnancy   glucose   insulin       bmi       dpf       age   outcome
# 0     0.639947  0.848324 -0.692891  0.204013  0.468492  1.425995  1.365896
# 1    -0.844885 -1.123396 -0.692891 -0.684422 -0.365061 -0.190672 -0.732120
# 2     1.233880  1.943724 -0.692891 -1.103255  0.604397 -0.105584  1.365896
# 3    -0.844885 -0.998208  0.123302 -0.494043 -0.920763 -1.041549 -0.732120
# 4    -1.141852  0.504055  0.765836  1.409746  5.484909 -0.020496  1.365896
# ..         ...       ...       ...       ...       ...       ...       ...
# 763   1.827813 -0.622642  0.870031  0.115169 -0.908682  2.532136 -0.732120
# 764  -0.547919  0.034598 -0.692891  0.610154 -0.398282 -0.531023 -0.732120
# 765   0.342981  0.003301  0.279594 -0.735190 -0.685193 -0.275760 -0.732120
# 766  -0.844885  0.159787 -0.692891 -0.240205 -0.371101  1.170732  1.365896
# 767  -0.844885 -0.873019 -0.692891 -0.202129 -0.473785 -0.871374 -0.732120
#
# [768 rows x 7 columns]

# %%
z=np.abs(zscore(df))# c convert all value to positive using absolute method of numpy

# %%
z #only positive value
# Out:
#      pregnancy   glucose   insulin       bmi       dpf       age   outcome
# 0     0.639947  0.848324  0.692891  0.204013  0.468492  1.425995  1.365896
# 1     0.844885  1.123396  0.692891  0.684422  0.365061  0.190672  0.732120
# 2     1.233880  1.943724  0.692891  1.103255  0.604397  0.105584  1.365896
# 3     0.844885  0.998208  0.123302  0.494043  0.920763  1.041549  0.732120
# 4     1.141852  0.504055  0.765836  1.409746  5.484909  0.020496  1.365896
# ..         ...       ...       ...       ...       ...       ...       ...
# 763   1.827813  0.622642  0.870031  0.115169  0.908682  2.532136  0.732120
# 764   0.547919  0.034598  0.692891  0.610154  0.398282  0.531023  0.732120
# 765   0.342981  0.003301  0.279594  0.735190  0.685193  0.275760  0.732120
# 766   0.844885  0.159787  0.692891  0.240205  0.371101  1.170732  1.365896
# 767   0.844885  0.873019  0.692891  0.202129  0.473785  0.871374  0.732120
#
# [768 rows x 7 columns]

# %%
z.shape
# Out:
# (768, 7)

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
# index no.

np.where(z>3) # these are the row no. and column no. of  outliers present
# Out:
# (array([  4,   8,   9,  13,  45,  49,  58,  60,  75,  81,  88, 111, 123,
#         145, 153, 159, 177, 182, 186, 220, 228, 228, 247, 286, 298, 330,
#         342, 349, 370, 370, 371, 371, 395, 409, 415, 426, 445, 445, 453,
#         455, 459, 486, 494, 502, 522, 584, 593, 621, 645, 655, 666, 673,
#         684, 684, 695, 706, 753], dtype=int64),
#  array([4, 2, 3, 2, 4, 3, 4, 3, 1, 3, 0, 2, 5, 3, 2, 0, 3, 1, 2, 2, 2, 4,
#         2, 2, 0, 4, 1, 1, 2, 4, 3, 4, 4, 2, 2, 3, 3, 4, 5, 0, 5, 2, 3, 1,
#         3, 2, 4, 4, 2, 2, 5, 3, 3, 5, 2, 3, 2], dtype=int64))

# %%
z.iloc[9][3] # check outlier
# Out:
# 4.060473872668307

# %%
z.iloc[4][4]
# Out:
# 5.48490910046695

# %%
len(np.where(z>3)[0])# chech how many outliers prent if lery large then we can not drop bcz data loss happened
# Out:
# 57

# %% [markdown]
# # pandas axis=1 (column)
#          axis=0 (row)
#
# # numpy axis=0 (column)
#          axis=1 (row)

# %%
# 57 is not to much so we can remove outliers

df_new=df[(z<3).all(axis=1)]

# %%
print("old dataframe  ="  ,df.shape)
print("new dataframe = ",df_new.shape)
print("total drop = " ,df.shape[0]-df_new.shape[0])
# Out:
# old dataframe  = (768, 7)
# new dataframe =  (716, 7)
# total drop =  52

# %% [markdown]
# # Percentage data loss

# %%
loss_pecentage=(768-716)/768*100
loss_pecentage
# Out:
# 6.770833333333333

# %% [markdown]
# #checking how much outliers still there if the outliers there helps it testing the model or not

# %% [markdown]
# # model without outliers is df and model with desire outliers indf_new1

# %% [markdown]
# devide data into features and vectors

# %%
df_new
# Out:
#      pregnancy  glucose  insulin   bmi    dpf  age  outcome
# 0            6      148        0  33.6  0.627   50        1
# 1            1       85        0  26.6  0.351   31        0
# 2            8      183        0  23.3  0.672   32        1
# 3            1       89       94  28.1  0.167   21        0
# 5            5      116        0  25.6  0.201   30        0
# ..         ...      ...      ...   ...    ...  ...      ...
# 763         10      101      180  32.9  0.171   63        0
# 764          2      122        0  36.8  0.340   27        0
# 765          5      121      112  26.2  0.245   30        0
# 766          1      126        0  30.1  0.349   47        1
# 767          1       93        0  30.4  0.315   23        0
#
# [716 rows x 7 columns]

# %% [markdown]
# # seperate the data

# %%
# independent or input data

x=df_new.iloc[: ,:-1]

# %%
# target data
y=df_new.iloc[: ,-1]

# %%
x
# Out:
#      pregnancy  glucose  insulin   bmi    dpf  age
# 0            6      148        0  33.6  0.627   50
# 1            1       85        0  26.6  0.351   31
# 2            8      183        0  23.3  0.672   32
# 3            1       89       94  28.1  0.167   21
# 5            5      116        0  25.6  0.201   30
# ..         ...      ...      ...   ...    ...  ...
# 763         10      101      180  32.9  0.171   63
# 764          2      122        0  36.8  0.340   27
# 765          5      121      112  26.2  0.245   30
# 766          1      126        0  30.1  0.349   47
# 767          1       93        0  30.4  0.315   23
#
# [716 rows x 6 columns]

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 5      0
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: outcome, Length: 716, dtype: int64

# %% [markdown]
# # TRANSFORM DATA TO REMOVE SKEWNESS

# %%
from sklearn.preprocessing import power_transform

x=power_transform(x,method="yeo-johnson")# we can also use box-cox by defalt yeo-johnson

# %%
type(x) # our input x is dataframe but outut datatype is numpy aaray

#so when we use preprocessing always result comes in numpy type so we have to convert back into dataframe
# Out:
# numpy.ndarray

# %%
x # ML always work in two dimentional array
# Out:
# array([[ 0.81766344,  0.95218058, -1.00223104,  0.28114356,  0.86495337,
#          1.39031405],
#        [-0.84957557, -1.28238174, -1.00223104, -0.83047682, -0.16002044,
#          0.12808007],
#        [ 1.20277392,  1.82893792, -1.00223104, -1.43279399,  0.98450779,
#          0.23328673],
#        ...,
#        [ 0.59040907,  0.13114807,  0.96157194, -0.9003888 , -0.75346236,
#          0.0156547 ],
#        [-0.84957557,  0.29534181, -1.00223104, -0.25021575, -0.1698999 ,
#          1.26101626],
#        [-0.84957557, -0.92550642, -1.00223104, -0.2028927 , -0.34504064,
#         -1.05311184]])

# %%
x.ndim # check dimention of array
# Out:
# 2

# %%
#from sklearn.preprocessing import StandardScaler  # scalling

# transform data into normalization

#sc= StandardScaler()
#x=sc.fit_transform(x)
#x


# no need to scalling bcz our data is already normalized doring removing skewness using power_transform methodx

# %%
x.mean() # this value is closest to zero
# Out:
# 2.395972929679877e-15

# %%
round(2.395972929679877e-15)==0
# Out:
# True

# %%
x.std()  # std=1 and mean =0 means our data is normalized
# Out:
# 1.0

# %% [markdown]
# # since the outcome has only two classes so we will use binary classification model

# %%
df_new.outcome.unique()
# Out:
# array([1, 0], dtype=int64)

# %%
df_new.outcome.value_counts()
# Out:
# 0    473
# 1    243
# Name: outcome, dtype: int64

# %%
ds=pd.DataFrame(data=df_new)

# %%
ds
# Out:
#      pregnancy  glucose  insulin   bmi    dpf  age  outcome
# 0            6      148        0  33.6  0.627   50        1
# 1            1       85        0  26.6  0.351   31        0
# 2            8      183        0  23.3  0.672   32        1
# 3            1       89       94  28.1  0.167   21        0
# 5            5      116        0  25.6  0.201   30        0
# ..         ...      ...      ...   ...    ...  ...      ...
# 763         10      101      180  32.9  0.171   63        0
# 764          2      122        0  36.8  0.340   27        0
# 765          5      121      112  26.2  0.245   30        0
# 766          1      126        0  30.1  0.349   47        1
# 767          1       93        0  30.4  0.315   23        0
#
# [716 rows x 7 columns]

# %%
x_new=ds.iloc[:, :-1]
y_new=ds.iloc[:, -1]

# %%
x_new
# Out:
#      pregnancy  glucose  insulin   bmi    dpf  age
# 0            6      148        0  33.6  0.627   50
# 1            1       85        0  26.6  0.351   31
# 2            8      183        0  23.3  0.672   32
# 3            1       89       94  28.1  0.167   21
# 5            5      116        0  25.6  0.201   30
# ..         ...      ...      ...   ...    ...  ...
# 763         10      101      180  32.9  0.171   63
# 764          2      122        0  36.8  0.340   27
# 765          5      121      112  26.2  0.245   30
# 766          1      126        0  30.1  0.349   47
# 767          1       93        0  30.4  0.315   23
#
# [716 rows x 6 columns]

# %%
y_new
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 5      0
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: outcome, Length: 716, dtype: int64

# %% [markdown]
# # balancing the dataset

# %% [markdown]
# use oversampling method to solve the inbalance data using SMOTE

# %%
from imblearn.over_sampling import SMOTE

smt=SMOTE()# instance of smote

# %%
trainx,trainy=smt.fit_resample(x_new,y_new)

# %%
trainx.value_counts()
# Out:
# pregnancy  glucose  insulin  bmi        dpf       age
# 0          57       0        21.700000  0.735000  67     1
# 5          147      0        33.700000  0.218000  65     1
#            128      0        34.600000  0.144000  45     1
#            130      0        39.051916  0.953017  37     1
#                              39.100000  0.956000  37     1
#                                                         ..
# 2          105      0        23.300000  0.560000  53     1
#                     94       34.900000  0.225000  25     1
#                     191      33.700000  0.711000  29     1
#            106      49       24.211847  0.657403  22     1
# 13         158      0        42.300000  0.257000  44     1
# Length: 946, dtype: int64

# %%
trainy.value_counts()
# Out:
# 1    473
# 0    473
# Name: outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split

from sklearn.linear_model import LogisticRegression



from sklearn.metrics import accuracy_score

# %% [markdown]
# # spit the dataset

# %% [markdown]
# # decide the value of random state

# %%
# decide the value of random state for model efficiency

# %%
lr=LogisticRegression()
 
for i in range(0,1000):
    x_train, x_test, y_train, y_test = train_test_split( trainx, trainy, test_size=.25, random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if(round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1)):
        print(" at random state ", i, "the model perform very well")
        print(" at random state =", i)
        print("training accurecy score is=",(round(accuracy_score(y_train,pred_train)*100,1)))
        print("testing accurecy score is=",(round(accuracy_score(y_test,pred_test)*100,1)))
# Out:
#  at random state  2 the model perform very well
#  at random state = 2
# training accurecy score is= 75.5
# testing accurecy score is= 75.5
#  at random state  120 the model perform very well
#  at random state = 120
# training accurecy score is= 75.9
# testing accurecy score is= 75.9
#  at random state  161 the model perform very well
#  at random state = 161
# training accurecy score is= 75.9
# testing accurecy score is= 75.9
#  at random state  186 the model perform very well
#  at random state = 186
# training accurecy score is= 75.9
# testing accurecy score is= 75.9
#  at random state  249 the model perform very well
#  at random state = 249
# training accurecy score is= 75.9
# testing accurecy score is= 75.9
#  at random state  286 the model perform very well
#  at random state = 286
# training accurecy score is= 75.5
# testing accurecy score is= 75.5
#  at random state  288 the model perform very well
#  at random state = 288
# training accurecy score is= 75.5
# ...

# %%
  x_train, x_test, y_train, y_test = train_test_split( trainx, trainy, test_size=.25, random_state=120)

# %% [markdown]
# # logistic regression

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.fit(x_train,y_train)
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)

# %%
print(accuracy_score(y_train,pred_train))
# Out:
# 0.7588152327221439

# %%
print(accuracy_score(y_test,pred_test))
# Out:
# 0.759493670886076

# %%
from sklearn.metrics import classification_report
print( classification_report(y_test,pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.81      0.78       127
#            1       0.76      0.70      0.73       110
#
#     accuracy                           0.76       237
#    macro avg       0.76      0.76      0.76       237
# weighted avg       0.76      0.76      0.76       237

# %% [markdown]
# # cross validation scote for logistic regression

# %% [markdown]
# control overfing and underfiting

# %%
pred_lr=lr.predict(x_test)

from sklearn.model_selection import cross_val_score

lss=accuracy_score(y_test,pred_lr)

# %%
for j in range(4,10):
    lsscore=cross_val_score(lr,trainx,trainy,cv=j)
    print(lsscore)
    lsc=lsscore.mean()
    
    print(" At cv =",j)
    
    print("cross validation score is",lsc*100)
    
    print("acurecy score is",lss*100)
    
    print("/n ")
# Out:
# [0.70042194 0.77637131 0.75       0.78389831]
#  At cv = 4
# cross validation score is 75.26728885074733
# acurecy score is 75.9493670886076
# /n
# [0.70526316 0.75132275 0.74074074 0.78306878 0.77777778]
#  At cv = 5
# cross validation score is 75.1634642160958
# acurecy score is 75.9493670886076
# /n
# [0.71518987 0.71518987 0.78481013 0.74683544 0.80254777 0.75159236]
#  At cv = 6
# cross validation score is 75.26942406407052
# acurecy score is 75.9493670886076
# /n
# [0.70588235 0.74074074 0.74814815 0.73333333 0.76296296 0.81481481
#  0.73333333]
#  At cv = 7
# cross validation score is 74.84593837535014
# acurecy score is 75.9493670886076
# /n
# [0.67226891 0.72268908 0.73728814 0.78813559 0.72033898 0.77966102
#  0.81355932 0.74576271]
#  At cv = 8
# cross validation score is 74.74629682381428
# acurecy score is 75.9493670886076
# /n
# [0.66037736 0.73333333 0.71428571 0.78095238 0.75238095 0.75238095
#  0.77142857 0.80952381 0.74285714]
#  At cv = 9
# ...

# %%
lsscore_selected=cross_val_score(lr,trainx,trainy,cv=4).mean()
print("the cv score is ",lsscore_selected,"/n the accurecy score is:",lss)
# Out:
# the cv score is  0.7526728885074734 /n the accurecy score is: 0.759493670886076

# %%
from sklearn.metrics import confusion_matrix

# %%
# model_selection is function  created bcz when we want to use another model then only call this function

def model_selection(algorithm_instance,x_train, x_test, y_train, y_test):
    algorithm_instance.fit(x_train,y_train)
    model1_pred_train=algorithm_instance.predict(x_train)
    model1_pred_test=algorithm_instance.predict(x_test)
    
    print('accuracy score of training data',accuracy_score(y_train, model1_pred_train))
    print('accuracy score of testing data',accuracy_score(y_test, model1_pred_test))
          
  
    print(",classification_report of train data ",classification_report(y_train, model1_pred_train))
    print(",classification_report of test data ",classification_report(y_test, model1_pred_test))
    
    print("confusion_matrix",confusion_matrix(y_test, model1_pred_test))

# %%
 model_selection(lr,x_train, x_test, y_train, y_test)
# Out:
# accuracy score of training data 0.7588152327221439
# accuracy score of testing data 0.759493670886076
# ,classification_report of train data                precision    recall  f1-score   support
#
#            0       0.74      0.78      0.76       346
#            1       0.78      0.74      0.76       363
#
#     accuracy                           0.76       709
#    macro avg       0.76      0.76      0.76       709
# weighted avg       0.76      0.76      0.76       709
#
# ,classification_report of test data                precision    recall  f1-score   support
#
#            0       0.76      0.81      0.78       127
#            1       0.76      0.70      0.73       110
#
#     accuracy                           0.76       237
#    macro avg       0.76      0.76      0.76       237
# weighted avg       0.76      0.76      0.76       237
#
# confusion_matrix [[103  24]
#  [ 33  77]]

# %%
# other model dtc

from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()

# %%
 model_selection(dtc,x_train, x_test, y_train, y_test)
# Out:
# accuracy score of training data 1.0
# accuracy score of testing data 0.7341772151898734
# ,classification_report of train data                precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       346
#            1       1.00      1.00      1.00       363
#
#     accuracy                           1.00       709
#    macro avg       1.00      1.00      1.00       709
# weighted avg       1.00      1.00      1.00       709
#
# ,classification_report of test data                precision    recall  f1-score   support
#
#            0       0.75      0.76      0.75       127
#            1       0.72      0.70      0.71       110
#
#     accuracy                           0.73       237
#    macro avg       0.73      0.73      0.73       237
# weighted avg       0.73      0.73      0.73       237
#
# confusion_matrix [[97 30]
#  [33 77]]

# %%
from  sklearn.naive_bayes import MultinomialNB

from sklearn.neighbors import KNeighborsClassifier

from sklearn.svm import SVC

knn=KNeighborsClassifier()
mnb=MultinomialNB()
sv=SVC()

# %%
model_selection(knn,x_train, x_test, y_train, y_test)
# Out:
# accuracy score of training data 0.8307475317348378
# accuracy score of testing data 0.7172995780590717
# ,classification_report of train data                precision    recall  f1-score   support
#
#            0       0.88      0.76      0.81       346
#            1       0.80      0.90      0.84       363
#
#     accuracy                           0.83       709
#    macro avg       0.84      0.83      0.83       709
# weighted avg       0.84      0.83      0.83       709
#
# ,classification_report of test data                precision    recall  f1-score   support
#
#            0       0.79      0.65      0.71       127
#            1       0.66      0.80      0.72       110
#
#     accuracy                           0.72       237
#    macro avg       0.73      0.72      0.72       237
# weighted avg       0.73      0.72      0.72       237
#
# confusion_matrix [[82 45]
#  [22 88]]

# %%
model_selection(mnb,x_train, x_test, y_train, y_test)
# Out:
# accuracy score of training data 0.5345557122708039
# accuracy score of testing data 0.48523206751054854
# ,classification_report of train data                precision    recall  f1-score   support
#
#            0       0.52      0.60      0.56       346
#            1       0.55      0.47      0.51       363
#
#     accuracy                           0.53       709
#    macro avg       0.54      0.54      0.53       709
# weighted avg       0.54      0.53      0.53       709
#
# ,classification_report of test data                precision    recall  f1-score   support
#
#            0       0.52      0.57      0.54       127
#            1       0.44      0.38      0.41       110
#
#     accuracy                           0.49       237
#    macro avg       0.48      0.48      0.48       237
# weighted avg       0.48      0.49      0.48       237
#
# confusion_matrix [[73 54]
#  [68 42]]

# %%
model_selection(sv,x_train, x_test, y_train, y_test)
# Out:
# accuracy score of training data 0.7433004231311706
# accuracy score of testing data 0.7383966244725738
# ,classification_report of train data                precision    recall  f1-score   support
#
#            0       0.75      0.70      0.73       346
#            1       0.73      0.78      0.76       363
#
#     accuracy                           0.74       709
#    macro avg       0.74      0.74      0.74       709
# weighted avg       0.74      0.74      0.74       709
#
# ,classification_report of test data                precision    recall  f1-score   support
#
#            0       0.77      0.72      0.75       127
#            1       0.70      0.75      0.73       110
#
#     accuracy                           0.74       237
#    macro avg       0.74      0.74      0.74       237
# weighted avg       0.74      0.74      0.74       237
#
# confusion_matrix [[92 35]
#  [27 83]]

# %% [markdown]
# # the model with the outliers

# %% [markdown]
# # AUC ROC CURV

# %%
from sklearn.metrics import roc_curve,auc
fpr,tpr ,thresold=roc_curve(pred_test,y_test)
roc_auc=auc(fpr,tpr)

plt.figure()
plt.plot(fpr,tpr,color="darkorange",lw=10,label= "roc curve(area=%0.2f)"% roc_auc)
plt.plot([0,1],[0,1],color="navy",lw=10,linestyle="--")# defalt model
plt.xlim([0.0,1.0])# limitation
plt.ylim([0.0,1.05])
plt.xlabel("false positive rate")
plt.ylabel("true positive rate")
plt.title("receiver operating characterstics")
plt.legend(loc="lower right")
plt.show()

# %%
best value of thresold is automaticaly collected
fpr- false positive rate 
tpr- true positive rate
roc- receiver operating curve

# %% [markdown]
# # since the model without outlier performing well we will select the dataframe
#
#
# not to good bu atleast above 50%

# %% [markdown]
# # model saving

# %%
import pickle
filename_1="inhouse_diabetes.pkl"
pickle.dump(lr,open(filename_1,"wb"))

# %% [markdown]
# # conclusion

# %%
original=np.array(y_test)
predicted=np.array(lr.predict(x_test))

df_com=pd.DataFrame({"original":original,"predicted":predicted},index=range(len(original)))
df_com
# Out:
#      original  predicted
# 0           1          1
# 1           0          0
# 2           0          0
# 3           0          1
# 4           1          1
# ..        ...        ...
# 232         0          0
# 233         0          1
# 234         0          0
# 235         1          0
# 236         0          0
#
# [237 rows x 2 columns]
